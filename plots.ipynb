# %% [markdown]
# This notebook is used to plot histograms and scatter plots of features in the honey production and air quality datasets.<br>
# First, imports and read in the data

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

honey_data = pd.read_csv('honeyproduction.csv')

# %%
sns.histplot(data=honey_data, x="yieldpercol").set_title("Distribution of Bee Colony Yields in the US 1998-2012")
# Out:
# Text(0.5, 1.0, 'Distribution of Bee Colony Yields in the US 1998-2012')

# %%
sns.histplot(data=honey_data, x="year", bins=15).set_title("Number of Honey Production Data Points per Year")
# Out:
# Text(0.5, 1.0, 'Number of Honey Production Data Points per Year')

# %% [markdown]
# Things to plot:
# - Scatter plot of PM2.5 vs. bee production with regression line
# - Scatter plot of other air quality measures bee production
